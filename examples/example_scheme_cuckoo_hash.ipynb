# %%
from IPython.core.display import display, HTML
# resize the cell in notebook sheet to as large as possible
display(HTML("""
<style>
.container { 
    width:100% !important;
    margin-left:0 !important;
}
</style>
</style>"""))

from jupyter_widget_hwt.scheme import HwtSchemeWidget
from hwtLib.mem.cuckooHashTable import CuckooHashTable

u = CuckooHashTable()
u.KEY_WIDTH = 16
u.DATA_WIDTH = 8
u.LOOKUP_KEY = True
u.TABLE_SIZE = 32

# not that this component is very large and complicated
HwtSchemeWidget(u, width=1500, height=1000)
# Out:
# <style>
# .container {
#     width:100% !important;
#     margin-left:0 !important;
# }
# </style>
# </style>
# HwtSchemeWidget(height='1000px', value={'hwMeta': {'name': 'CuckooHashTable', 'cls': None, 'maxId': 1427}, 'pr…
